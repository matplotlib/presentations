# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
# Out:
# <img src="data:image/png;base64,...">

# %%
plt.show()

# %%
ax.plot(range(3))

# %%
ln, = _
ln.set_color('r')

# %%
ln.set_lw(5)
