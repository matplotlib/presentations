# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
fig = plt.gcf()
ax = plt.gca()
ax.plot(np.cumsum(np.random.random(1000)-0.5))
# Out:
# <img src="data:image/png;base64,...">

# %% [markdown]
# Displaying figure currently displays a PNG:

# %%
fig

# %% [markdown]
# If we register `fig.canvas.manager.reshow` with `ipython_display_formatter`,
# it will redisplay the interactive figure:

# %%
ipf = get_ipython().display_formatter.ipython_display_formatter
ipf.for_type(plt.Figure, lambda fig: fig.canvas.manager.reshow())

# %%
fig
# Out:
# <img src="data:image/png;base64,...">

# %%
fig, ax = plt.subplots()
fig
# Out:
# <img src="data:image/png;base64,...">
# <img src="data:image/png;base64,...">

# %%
plt.subplots()
# Out:
# <img src="data:image/png;base64,...">
# (<matplotlib.figure.Figure at 0x7fb2659f8c88>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fb2657ba390>)

# %%
plt.gcf()
# Out:
# <img src="data:image/png;base64,...">
